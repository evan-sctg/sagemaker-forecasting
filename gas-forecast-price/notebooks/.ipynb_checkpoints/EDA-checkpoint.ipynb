# %%
import os
import sagemaker
from hydra import compose, initialize, core
from omegaconf import OmegaConf
import pandas as pd
import numpy as np
import pmdarima as pm
import matplotlib.pyplot as plt
from sktime.utils.plotting import plot_correlations
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import STL
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
core.global_hydra.GlobalHydra.instance().clear()
initialize(version_base='1.2', config_path='../src/config', job_name='eda')
config = OmegaConf.to_container(compose(config_name='main'), resolve=True)

# %%
# !wget -q {config['raw_data_url']} -O gas_data.xls

# %%
gas_data = pd.read_excel(
    'gas_data.xls',
    sheet_name='Data 1',
    header=2, # The column names start on the 3rd row
    index_col='Date'
)

#print(gas_data.columns)
gas_data=gas_data[['Weekly U.S. Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)']]
gas_data.columns = ['price_per_gallon']

gas_data.shape
# Out:
# (1766, 1)

# %%
pd.DataFrame.from_dict(gas_data)
# Out:
#             price_per_gallon
# Date
# 1990-08-20             1.191
# 1990-08-27             1.245
# 1990-09-03             1.242
# 1990-09-10             1.252
# 1990-09-17             1.266
# ...                      ...
# 2024-05-20             3.451
# 2024-05-27             3.434
# 2024-06-03             3.376
# 2024-06-10             3.297
# 2024-06-17             3.310
#
# [1766 rows x 1 columns]

# %%
if gas_data['price_per_gallon'].isna().sum() > 0:
    gas_data['price_per_gallon'] = gas_data['price_per_gallon'].interpolate()

# %%
assert gas_data['price_per_gallon'].isna().sum() == 0
assert gas_data.index.duplicated(keep=False).sum() == 0

# %%
gas_data['price_per_gallon'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
np.log(gas_data['price_per_gallon']).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
gas_data.index[0] , gas_data.index[-1]
# Out:
# (Timestamp('1990-08-20 00:00:00'), Timestamp('2024-06-17 00:00:00'))

# %%
train, test = pm.model_selection.train_test_split(gas_data, test_size=config['forecast_horizon'])
print(f'The training period is {train.index.min().strftime("%Y-%m-%d")} to {train.index.max().strftime("%Y-%m-%d")}')
print(f'The test period is {test.index.min().strftime("%Y-%m-%d")} to {test.index.max().strftime("%Y-%m-%d")}')
# Out:
# The training period is 1990-08-20 to 2023-12-18
# The test period is 2023-12-25 to 2024-06-17

# %%
lags = np.min([2 * (365.25 / 7), (gas_data.shape[0] / 5)])

fig, ax = plot_correlations(
    series=gas_data['price_per_gallon'],
    lags=lags,
    zero_lag=False,
    suptitle='Weekly U.S. Gasoline Price'
)
fig.set_size_inches((16, 5))
plt.show()

# %%
fig = plot_acf(
    x=gas_data['price_per_gallon'], 
    lags=lags,
    zero=False
)
fig.set_size_inches(12, 6)
plt.axvline(x=52, color='r', linestyle='--', label='Lag 52')
plt.axvline(x=104, color='g', linestyle='--', label='Lag 104')
plt.legend()
plt.show();

# %%
fig = plot_pacf(
    x=gas_data['price_per_gallon'], 
    lags=lags,
    zero=False
)
fig.set_size_inches(12, 6)
plt.axvline(x=52, color='r', linestyle='--', label='Lag 52')
plt.axvline(x=104, color='g', linestyle='--', label='Lag 104')
plt.legend()
plt.show();

# %%
gas_data.resample('YS').mean().plot(y='price_per_gallon', figsize=(7, 5), title='Average Gas Price by Year');

# %%
gas_data.resample('YS').var().plot(y='price_per_gallon', figsize=(7, 5), title='Variance of Gas Price by Year');

# %%
gas_data['price_per_gallon'].loc['2020':'2023'].plot(figsize=(15, 5), title='Gas Price (2020 - 2023)');

# %%
m = (365.25 / 7)
decomp_result = STL(endog=pd.Series(gas_data['price_per_gallon'], name='Seasonal-Trend Decomposition of Gas Price'), period=int(np.floor(m)), robust=True).fit()
fig = decomp_result.plot()
fig.set_size_inches(12, 8)
plt.show();

# %%
resid_75 = np.quantile(decomp_result._resid, 0.75)
resid_25 = np.quantile(decomp_result._resid, 0.25)
resid_iqr = resid_75 - resid_25

# Indices of outliers
outlier_indices = np.logical_or((decomp_result._resid > resid_75 + 3 * resid_iqr), (decomp_result._resid < resid_25 - 3 * resid_iqr))
outlier_indices.sum()
# Out:
# 279

# %%
earliest = gas_data.loc[(outlier_indices)].loc['2020'].index.min().strftime('%Y-%m-%d')
latest = gas_data.loc[(outlier_indices)].index.max().strftime('%Y-%m-%d')
print(f'The outlier with the earliest date within the COVID-19 years is {earliest}')
print(f'The outlier with the latest date within the COVID-19 years is {latest}')
# Out:
# The outlier with the earliest date within the COVID-19 years is 2020-01-06
# The outlier with the latest date within the COVID-19 years is 2023-11-20

# %%
train['covid_forecast'] = np.logical_and((train.index >= earliest), (train.index <= latest))
test['covid_forecast'] = False

# %%
pd.DataFrame.from_dict(train)
# Out:
#             price_per_gallon  covid_forecast
# Date
# 1990-08-20             1.191           False
# 1990-08-27             1.245           False
# 1990-09-03             1.242           False
# 1990-09-10             1.252           False
# 1990-09-17             1.266           False
# ...                      ...             ...
# 2023-11-20             3.144            True
# 2023-11-27             3.088           False
# 2023-12-04             3.104           False
# 2023-12-11             3.014           False
# 2023-12-18             2.931           False
#
# [1740 rows x 2 columns]

# %%
# Save the outlier indices to the current directory
pd.concat([train, test], axis=0).to_csv('gas_data.csv', index=True)

# Upload both the raw data and the outlier indices to s3
sagemaker.s3.S3Uploader.upload('gas_data.csv', f's3://{config["s3_bucket"]}/{config["s3_key"]}/raw-data')

# Remove from the current directory
os.remove('gas_data.csv')
os.remove('gas_data.xls')
